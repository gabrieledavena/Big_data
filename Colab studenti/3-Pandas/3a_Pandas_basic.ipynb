# %% [markdown]
# # Getting started with Pandas
#
# 1. Official Pandas tutorial (https://pandas.pydata.org/)
# 2. Pandas is one of the most used library for data science

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Pandas has two main data structures:
#
# 1. Series
#
# 2. Dataframe

# %%
# from pandas import Series, DataFrame

# %% [markdown]
# ## **Series**
# 1. Sequence of values, similar to numpy array
# 2. Each data value is associated to a label
#   - Left side represents the index (data labels)
#   - Right side represents the data

# %% [markdown]
# ### Create a Series

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
type(obj.values)
# Out:
# numpy.ndarray

# %%
obj.index  # like range(4)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
type(obj.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# - We can specify the labels.

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
type(obj2.index)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ### Numpy-like operations
# 1. Filtering with a boolean array
# 2. Scalar multiplication
# 3. Applying math functions
#
# They will preserve the index-value link

# %%
obj2['b']
# Out:
# np.int64(7)

# %%
obj2['b']=4

# %%
obj2['b']
# Out:
# np.int64(4)

# %%
obj2
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
obj2[:'a']    # obj2[:3]    ATTENZIONE!!!
# Out:
# d    4
# b    4
# a   -5
# dtype: int64

# %%
type(obj2[:2])
# Out:
# pandas.core.series.Series

# %%
obj2
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
obj2[['c', 'a', 'd', 'd', 'a']]
# Out:
# c    3
# a   -5
# d    4
# d    4
# a   -5
# dtype: int64

# %%
type(obj2[['c', 'a', 'd', 'd', 'a']])
# Out:
# pandas.core.series.Series

# %%
obj2>2
# Out:
# d     True
# b     True
# a    False
# c     True
# dtype: bool

# %%
type(obj2>2)
# Out:
# pandas.core.series.Series

# %%
obj2[obj2 > 2]
# Out:
# d    4
# b    4
# c    3
# dtype: int64

# %%
type(obj2[obj2 > 2])
# Out:
# pandas.core.series.Series

# %%
'a' in obj2    # controllo se un valore è tra gli indici della Series
# Out:
# True

# %%
3 in obj2
# Out:
# False

# %%
3 in obj2.values
# Out:
# True

# %%
obj2.isin([3])
# Out:
# d    False
# b    False
# a    False
# c     True
# dtype: bool

# %%
obj2 == 3
# Out:
# d    False
# b    False
# a    False
# c     True
# dtype: bool

# %%
(obj2 == 3).any()
# Out:
# np.True_

# %% [markdown]
# ### Math operations

# %% [markdown]
# Element wise casting
#
# Given $ X = \left[ x_1 \cdots x_n \right] $ then:<br> $ X * 2  = \left[ 2 x_1  \cdots 2{x_n} \right]
# $
#  <br> $
# e^X = \left[ e^{x_1} \cdots e^{x_n} \right]
# $

# %%
obj2
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d     8
# b     8
# a   -10
# c     6
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d    54.598150
# b    54.598150
# a     0.006738
# c    20.085537
# dtype: float64

# %% [markdown]
# ### Use alignment of indexes for some operations

# %%
obj3 = pd.Series([1,2,3], index=['a', 'b', 'c'])

# %%
obj4 = pd.Series([1,2,3], index=['a', 'd', 'e'])

# %%
obj3 + obj4
# Out:
# a    2.0
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# dtype: float64

# %%
obj3.add(obj4, fill_value=0)
# Out:
# a    2.0
# b    2.0
# c    3.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# ### From Series to Dictionary and viceversa

# %% [markdown]
# - Another way to think about a Series is as a fixed-length, ordered dict, as it is a mapping of index values to data values.

# %%
obj2
# Out:
# d    4
# b    4
# a   -5
# c    3
# dtype: int64

# %%
obj2.to_dict()
# Out:
# {'d': 4, 'b': 4, 'a': -5, 'c': 3}

# %%
obj2.to_dict().keys()
# Out:
# dict_keys(['d', 'b', 'a', 'c'])

# %%
obj2.to_dict().values()
# Out:
# dict_values([4, 4, -5, 3])

# %% [markdown]
# - The index of the resulting Series will have the dict's keys
# - The data values of the Series are the values of the dict

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj3.index
# Out:
# Index(['Ohio', 'Texas', 'Oregon', 'Utah'], dtype='object')

# %%
obj3.values
# Out:
# array([35000, 71000, 16000,  5000])

# %%
type(obj3)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - Selecting the values of the Series based on the index values and forcing the order of the index

# %%
sdata
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
states = ['Ohio', 'California', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# Ohio          35000.0
# California        NaN
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# Ohio          False
# California     True
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# Ohio           True
# California    False
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isnull()
# Out:
# Ohio          False
# California     True
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# ### Dropping entries: method *.drop*

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop('c')
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
new_obj = obj.drop('c')
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop('c', inplace=True)
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %% [markdown]
# ### Giving a name to the Series
# - The name of the Series becomes its index or column name if it is used to form a DataFrame.
# - It is also used whenever displaying the Series using the interpreter.

# %%
obj.name = 'population'
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# Name: population, dtype: float64

# %%
obj.index.name = 'state'

# %%
obj
# Out:
# state
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# Name: population, dtype: float64

# %% [markdown]
# ## **DataFrame**
# 1. Represents a rectangular table of data
# 2. Contains an ordered collection of columns
# 3. Has indexes on columns and rows
# 4. Each column can have a different type (i.e., numeric, string, boolean, etc.)

# %% [markdown]
# ### Create a Dataframe

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.shape
# Out:
# (6, 3)

# %%
frame.head(3) # default: 5
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
frame.tail(3)
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.sample() # default: 1
# Out:
#     state  year  pop
# 5  Nevada  2003  3.2

# %%
frame.columns
# Out:
# Index(['state', 'year', 'pop'], dtype='object')

# %%
frame.index.values
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# If you specify a sequence of columns, the DataFrame’s columns will be arranged in that order

# %%
data
# Out:
# {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002, 2003],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
pd.DataFrame(data, columns=['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %% [markdown]
# Also, you can sepcify the row index.

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four', 'five', 'six'])
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %% [markdown]
# ### Indexing and Selection

# %% [markdown]
# - A column in a DataFrame can be retrieved as a Series either by dict-like notation or by attribute

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
type(frame2['state'])
# Out:
# pandas.core.series.Series

# %%
frame2.state
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2['year'][0] # or frame2.year[0]
# Out:
# /var/folders/d5/jd8cs2ds0lq81wp6tr68x7800000gn/T/ipykernel_6693/3019913084.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   frame2['year'][0] # or frame2.year[0]
# np.int64(2000)

# %% [markdown]
# - Rows can also be retrieved by position or name with the special **loc** attribute

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
type(frame2.loc['three'])
# Out:
# pandas.core.series.Series

# %%
frame2.loc['three'][0]
# Out:
# /var/folders/d5/jd8cs2ds0lq81wp6tr68x7800000gn/T/ipykernel_6693/2260567952.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   frame2.loc['three'][0]
# np.int64(2002)

# %% [markdown]
# Other options:
# - ***loc***: Access a group of rows and columns by label(s).
# - ***iloc***: Purely integer-location based rows and columns indexing for selection by position.
# - **[   :   ,   :   ]**: Access rows by integer or labels, or access columns by labels (columns can be omitted).

# %%
data = pd.DataFrame(np.arange(20).reshape((4, 5)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['zero', 'one', 'two', 'three', 'four'])
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data.loc['Ohio':'Colorado','two']
# Out:
# Ohio        2
# Colorado    7
# Name: two, dtype: int64

# %%
data[1:] # equals to
# data.loc['Colorado':]
# data.iloc[1:]
# Out:
#           zero  one  two  three  four
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data[0:2] #--> [] by integer
# equals to
# data.loc['Ohio':'Colorado']
# data.iloc[0:2]
# data['Ohio':'Colorado'] # --> [] by label
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9

# %%
data[['one']]
# Out:
#           one
# Ohio        1
# Colorado    6
# Utah       11
# New York   16

# %%
data[['one','two']]
# Out:
#           one  two
# Ohio        1    2
# Colorado    6    7
# Utah       11   12
# New York   16   17

# %%
# data.loc['Colorado':'Utah','two':]# equal to
data.iloc[1:3,2:]
# Out:
#           two  three  four
# Colorado    7      8     9
# Utah       12     13    14

# %%
data.loc[:,'one'] # equal to data['one']
# Out:
# Ohio         1
# Colorado     6
# Utah        11
# New York    16
# Name: one, dtype: int64

# %%
data[['three', 'two', 'one']] # equals to
# data.loc[:,['three', 'two', 'one']]
# data.iloc[:,[2,1,0]]
# Out:
#           three  two  one
# Ohio          3    2    1
# Colorado      8    7    6
# Utah         13   12   11
# New York     18   17   16

# %%
data.loc[:, 'two':] # or
#data.iloc[:, 2:]
# data['two':] does not work
# Out:
#           two  three  four
# Ohio        2      3     4
# Colorado    7      8     9
# Utah       12     13    14
# New York   17     18    19

# %%
data.loc['Colorado']
# data['Colorado'] # does not work >>> None of [Index(['Colorado'], dtype='object')] are in the [columns] <<< --> in [] single labels are only for columns
# data.iloc[1]
# Out:
# zero     5
# one      6
# two      7
# three    8
# four     9
# Name: Colorado, dtype: int64

# %%
data.loc[['Colorado']]
# data['Colorado':'Colorado']
# data.iloc[[1]]
# Out:
#           zero  one  two  three  four
# Colorado     5    6    7      8     9

# %%
# Row and columns selection
# Examples
data.loc['Ohio':'Colorado', 'three'] # data.loc[[row], [col]] -> label
data.loc['Colorado', ['two', 'three']] # data
data.loc['Ohio':'Colorado', 'three':'four']
data.iloc[[1, 2], 1:2]
data.loc[:'Utah', 'two']
data.iloc[0:2, :] # data.iloc[[row], [col]] -> posizionale
data.iloc[2:3, [3, 0, 1]] # Utah, cols: four, one, two
# Out:
#       three  zero  one
# Utah     13    10   11

# %% [markdown]
# Why use loc? Differences between [] and .loc[]
#
# 1.   using **.loc**, the execution time is more than 3X times faster!
#
# 2.   loc is explicit: df.loc[row_indexer, column_index] can select rows and columns.
#
#  df[indexer] can only select rows or columns depending on the type of values in indexer and the type of column values the dataframe has.
#
# 3.  When a slice is passed to **df.loc** the **end-points are included** in the range. When a slice is passed to **df[...]**, the slice is interpreted as a **half-open** interval.

# %%
x = pd.DataFrame(np.arange(9).reshape(3,3))
x
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8

# %%
x.loc[1:2].index.values
# Out:
# array([1, 2])

# %%
x[1:2].index.values
# Out:
# array([1])

# %% [markdown]
# ### Filtering

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data['three'] > 5
# Out:
# Ohio        False
# Colorado     True
# Utah         True
# New York     True
# Name: three, dtype: bool

# %%
data[data['three'] > 5]
# data.loc[data['three'] > 5]
# data.iloc[data['three'] > 5] # NOT working >>> iLocation based boolean indexing cannot use an indexable as a mask
# Out:
#           zero  one  two  three  four
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data >= 12
# Out:
#            zero    one    two  three   four
# Ohio      False  False  False  False  False
# Colorado  False  False  False  False  False
# Utah      False  False   True   True   True
# New York   True   True   True   True   True

# %%
data[data >= 12]
# Does NOT work with loc & iloc
# Out:
#           zero   one   two  three  four
# Ohio       NaN   NaN   NaN    NaN   NaN
# Colorado   NaN   NaN   NaN    NaN   NaN
# Utah       NaN   NaN  12.0   13.0  14.0
# New York  15.0  16.0  17.0   18.0  19.0

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data.iloc[:, :3] [(data.three > 5) & (data['four'] <15)] # combination
# Out:
#           zero  one  two
# Colorado     5    6    7
# Utah        10   11   12

# %% [markdown]
# ### Modify a DataFrame

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_copy_reference = data

data_copy = data.copy()

data_view = data.iloc[2:,1:-1]

# %%
data_copy_reference
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_copy_reference[data_copy_reference >= 12] = 100
data_copy_reference
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11  100    100   100
# New York   100  100  100    100   100

# %%
data
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11  100    100   100
# New York   100  100  100    100   100

# %%
data_copy
# Out:
#           zero  one  two  three  four
# Ohio         0    1    2      3     4
# Colorado     5    6    7      8     9
# Utah        10   11   12     13    14
# New York    15   16   17     18    19

# %%
data_view
# Out:
#           one  two  three
# Utah       11  100    100
# New York  100  100    100

# %% [markdown]
# - Columns can be modified by assignment.

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2['debt'] = 16.5
frame2
# 16.5 is **broadcasted** to [16.5, 16.5, ...] == [16.5] * frame2['debt'].shape[0]
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %% [markdown]
# - When you are assigning lists or arrays to a column, the value’s length must match the length of the DataFrame.

# %%
frame2['debt'] = [2,15.7,80,98,12,12]
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   2.0
# two    2001    Ohio  1.7  15.7
# three  2002    Ohio  3.6  80.0
# four   2001  Nevada  2.4  98.0
# five   2002  Nevada  2.9  12.0
# six    2003  Nevada  3.2  12.0

# %%
# viene mantenuta l'associazione con i valori dell'indice

val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %% [markdown]
# ### Dropping entries from an axis: method *.drop*

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['two', 'four'], axis=1)
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# ### Arithmetic and Data Alignment

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])

df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])

# %%
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1 + df2
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %% [markdown]
# #### Arithmetic methods with fill values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))

# %%
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df2.loc[1, 'b'] = np.nan

# %%
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   NaN   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df1-df2
# Out:
#      a    b    c    d   e
# 0  0.0  0.0  0.0  0.0 NaN
# 1 -1.0  NaN -1.0 -1.0 NaN
# 2 -2.0 -2.0 -2.0 -2.0 NaN
# 3  NaN  NaN  NaN  NaN NaN

# %%
df1.sub(df2, fill_value=12000)
# Out:
#          a        b        c        d        e
# 0      0.0      0.0      0.0      0.0  11996.0
# 1     -1.0 -11995.0     -1.0     -1.0  11991.0
# 2     -2.0     -2.0     -2.0     -2.0  11986.0
# 3  11985.0  11984.0  11983.0  11982.0  11981.0

# %%
1 / df1
# Out:
#        a         b         c         d
# 0    inf  1.000000  0.500000  0.333333
# 1  0.250  0.200000  0.166667  0.142857
# 2  0.125  0.111111  0.100000  0.090909

# %%
df1 * 144
# Out:
#         a       b       c       d
# 0     0.0   144.0   288.0   432.0
# 1   576.0   720.0   864.0  1008.0
# 2  1152.0  1296.0  1440.0  1584.0

# %%
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %% [markdown]
# ### Re-indexing

# %%
df1
# Out:
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0

# %%
df1.reindex(columns=['a', 'd', 'b', 'f'], fill_value=100)
# Out:
#      a     d    b    f
# 0  0.0   3.0  1.0  100
# 1  4.0   7.0  5.0  100
# 2  8.0  11.0  9.0  100

# %% [markdown]
# ## Operations between DataFrame and Series

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
series2 = pd.Series(range(3), index=['b', 'e', 'f'])
series2
# Out:
# b    0
# e    1
# f    2
# dtype: int64

# %%
frame + series2
# Out:
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN

# %%
series3 = frame['d']
series3
# Out:
# Utah       1.0
# Ohio       4.0
# Texas      7.0
# Oregon    10.0
# Name: d, dtype: float64

# %%
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
frame + series3
# Out:
#         Ohio  Oregon  Texas  Utah   b   d   e
# Utah     NaN     NaN    NaN   NaN NaN NaN NaN
# Ohio     NaN     NaN    NaN   NaN NaN NaN NaN
# Texas    NaN     NaN    NaN   NaN NaN NaN NaN
# Oregon   NaN     NaN    NaN   NaN NaN NaN NaN

# %%
frame.add(series3, axis='index')
# Out:
#            b     d     e
# Utah     1.0   2.0   3.0
# Ohio     7.0   8.0   9.0
# Texas   13.0  14.0  15.0
# Oregon  19.0  20.0  21.0

# %% [markdown]
# ### Function Application and Mapping
#
# - *apply*: Apply a function along an axis of the DataFrame
# - *map*: Apply a function to a Dataframe elementwise. This method applies a function that accepts and returns a scalar to every element of a DataFrame

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    0.052321  0.984058 -0.237082
# Ohio   -0.403673  0.932413  0.965953
# Texas   1.897893 -1.106573  0.201709
# Oregon  0.446094 -0.350462 -0.380921

# %%
frame['b'].max()
# Out:
# np.float64(1.897893311348371)

# %%
frame['b'].min()
# Out:
# np.float64(-0.4036734200499287)

# %%
frame
# Out:
#                b         d         e
# Utah    0.052321  0.984058 -0.237082
# Ohio   -0.403673  0.932413  0.965953
# Texas   1.897893 -1.106573  0.201709
# Oregon  0.446094 -0.350462 -0.380921

# %%
def diff_max_min(x): # x pd.Series
  return x.max() - x.min()

# %%
frame.apply(diff_max_min)
# Out:
# b    2.301567
# d    2.090631
# e    1.346874
# dtype: float64

# %%
frame.apply(lambda x: x.max() - x.min())
# Out:
# b    2.301567
# d    2.090631
# e    1.346874
# dtype: float64

# %%
frame.apply(diff_max_min, axis='columns')
# Out:
# Utah      1.221140
# Ohio      1.369626
# Texas     3.004466
# Oregon    0.827016
# dtype: float64

# %%
def get_power_2(x): # x valore
  return np.power(x, 2)

frame.map(get_power_2)
# Out:
#                b         d         e
# Utah    0.002737  0.968371  0.056208
# Ohio    0.162952  0.869393  0.933065
# Texas   3.601999  1.224503  0.040686
# Oregon  0.199000  0.122824  0.145101

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %% [markdown]
# ### Describe

# %% [markdown]
# - describe
# - sum or cumsum
# - mean
# - count
# - value_counts

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                   [np.nan, np.nan], [0.75, -1.3]],
                  index=['a', 'b', 'c', 'd'],
                  columns=['one', 'two'])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     3 non-null      float64
#  1   two     2 non-null      float64
# dtypes: float64(2)
# memory usage: 268.0+ bytes

# %%
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis='columns')
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean(axis='columns', skipna=False)
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.max()
# Out:
# one    7.1
# two   -1.3
# dtype: float64

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(['c', 'a', 'c', 'a', 'a', 'b', 'b', 'c', 'c'])
obj
# Out:
# 0    c
# 1    a
# 2    c
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'b'], dtype=object)

# %%
obj.value_counts()
# Out:
# c    4
# a    3
# b    2
# Name: count, dtype: int64

# %%
obj
# Out:
# 0    c
# 1    a
# 2    c
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
obj.map(lambda x: x in ['c', 'a'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
mask = obj.isin(['c', 'a'])

# %%
mask
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
obj[mask]
# Out:
# 0    c
# 1    a
# 2    c
# 3    a
# 4    a
# 7    c
# 8    c
# dtype: object

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
                     'Qu2': [2, 3, 1, 2, 3],
                     'Qu3': [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
pd.value_counts(data["Qu1"])
# Out:
# /var/folders/d5/jd8cs2ds0lq81wp6tr68x7800000gn/T/ipykernel_6693/4286318968.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data["Qu1"])
# Qu1
# 3    2
# 4    2
# 1    1
# Name: count, dtype: int64
