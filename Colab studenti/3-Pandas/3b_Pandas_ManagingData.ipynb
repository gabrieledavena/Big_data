# %% [markdown]
# # Data Loading, Storage

# %%
import numpy as np
import pandas as pd

# %%
# You have to upload the data by using the Files function on your dashboard

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %% [markdown]
# Two methods:
# - *read_csv*: Read a comma-separated values (csv) file into DataFrame. Also supports optionally iterating or breaking of the file into chunks.
# - *to_csv*: Write object to a comma-separated values (csv) file.

# %% [markdown]
# ### Reading Text Files

# %%
# !cat "data/ex1.csv"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().system('cat "data/ex1.csv"')
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/ipykernel/zmqshell.py:685, in ZMQInteractiveShell.system_piped(self, cmd)
#     683         self.user_ns["_exit_code"] = system(cmd)
#     684 else:
# --> 685     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/IPython/utils/_process_posix.py:115, in ProcessHandler.system(self, cmd)
#     110 # The size of the output stored so far in the process output buffer.
#     111 # Since pexpect only appends to this buffer, each time we print we
#     112 # record how far we've printed, so that next time we only print *new*
#     113 # content from the buffer.
#     114 out_size = 0
# --> 115 assert self.sh is not None
#     116 try:
#     117     # Since we're not really searching the buffer for text patterns, we
#     118     # can set pexpect's search window to be tiny and it won't matter.
#     119     # We only search for the 'patterns' timeout or EOF, which aren't in
#     120     # the text itself.
#     121     #child = pexpect.spawn(pcmd, searchwindowsize=1)
#     122     if hasattr(pexpect, 'spawnb'):
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/IPython/utils/_process_posix.py:51, in ProcessHandler.sh(self)
#      49     self._sh = pexpect.which(shell_name)
#      50     if self._sh is None:
# ---> 51         raise OSError('"{}" shell not found'.format(shell_name))
#      53 return self._sh
#
# OSError: "/opt/homebrew/bin/zsh" shell not found

# %%
df = pd.read_csv("data/ex1.csv", sep=',')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(df)

# %% [markdown]
# #### Define separator value and header

# %%
# define the table sepator value

df = pd.read_csv('ex1.csv', sep='\t')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # define the table sepator value
# ----> 3 df = pd.read_csv('ex1.csv', sep='\t')
#       4 df
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ex1.csv'

# %%
# !cat "ex2.csv"

# %%
# define if the table header exists

pd.read_csv('ex2.csv', sep=',', header=None)

# %% [markdown]
# #### Define column name and/or index name

# %%
# define column name

pd.read_csv('data/ex2.csv', names=['a', 'b', 'c', 'd', 'message'])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# define index name

names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('data/ex2.csv', names=names, index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %% [markdown]
# #### Skip a list of row

# %%
# !cat "ex4.csv"

# %%
# you can skip a list of row
pd.read_csv('ex4.csv', skiprows=[0, 2, 3])

# %% [markdown]
# #### Handle null values

# %%
# !cat ex5.csv

# %%
result = pd.read_csv('data/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %% [markdown]
# define *na_values*

# %%
# !cat ex5.csv

# %%
result = pd.read_csv('ex5.csv', na_values=['one', 'foo'])
result

# %%
sentinels = {'message': ['foo'], 'something': ['two']}
pd.read_csv('ex5.csv', na_values=sentinels)

# %% [markdown]
# ### Reading Text Files in Pieces

# %% [markdown]
# #### Read only a fixed number of rows

# %%
pd.read_csv('ex6.csv', nrows=5)

# %% [markdown]
# #### Read Text Files in chunks

# %%
chunker = pd.read_csv('ex6.csv', chunksize=1000)
chunker

# %%
chunk = next(chunker)
chunk.head(5)

# %%
for i, chunk in enumerate(chunker):
  print("chunk #{} size: {}".format(i, chunk.shape))

# %% [markdown]
# ### Writing Data to Text Format

# %%
data = pd.read_csv('ex5.csv')
data

# %%
data.iloc[0,0] = 999

# %%
data

# %%
data.to_csv('out.csv')

# %%
# !cat out.csv

# %%
data.to_csv('out.csv',index=False)

# %%
# !cat out.csv

# %%
pd.read_csv('out.csv', sep=',')

# %%
data.to_csv('out.csv', index=False, sep='#')

# %%
# !cat out.csv

# %%
pd.read_csv('out.csv', sep='#')

# %% [markdown]
# ### Reading and Writing Microsoft Excel Files

# %% [markdown]
# Read option 1: Using *ExcelFile* class

# %%
xlsx = pd.ExcelFile('ex1.xlsx')

# %%
xlsx

# %% [markdown]
# Read option 2: Using *read_excel* method

# %%
frame = pd.read_excel('ex1.xlsx', 'Sheet1')
frame

# %% [markdown]
# Write: using *to_excel* method

# %%
frame.to_excel('ex2_out.xlsx')

# %% [markdown]
# ### Optional: Working with Delimited Formats

# %%
# !cat ex7.csv

# %%
import csv
f = open('ex7.csv')

reader = csv.reader(f)

# %%
for line in reader:
    print(line)

# %%
with open('ex7.csv') as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
header

# %%
values

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict

# %% [markdown]
# ## Optional

# %%
with open('ex3.txt', 'r') as f:
  lines = f.readlines()
lines

# %%
columns = [val.strip() for val in lines[0].split(' ') if val != '']
columns

# %%
data = []
for row in lines[1:]:
  res = [val.strip() for val in row.split(' ') if val != '']
  data.append(res)

# %%
data

# %%
columns

# %%
columns.insert(0, 'index')
columns

# %%
ds = pd.DataFrame(data, columns=columns)
ds

# %%
ds.set_index('index')
