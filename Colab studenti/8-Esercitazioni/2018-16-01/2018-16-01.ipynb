# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('BankMarketingDataSet.csv', sep=';')
df
# Out:
#         id  age          job  marital          education default  housing  \
# 0        1   30  blue-collar  married           basic.9y      no      yes
# 1        2   39     services   single        high.school      no       no
# 2        3   25     services  married        high.school      no      yes
# 3        4   38     services  married           basic.9y      no  unknown
# 4        5   47       admin.  married  university.degree      no      yes
# ...    ...  ...          ...      ...                ...     ...      ...
# 4114  4115   30       admin.  married           basic.6y      no      yes
# 4115  4116   39       admin.  married        high.school      no      yes
# 4116  4117   27      student   single        high.school      no       no
# 4117  4118   58       admin.  married        high.school      no       no
# 4118  4119   34   management   single        high.school      no      yes
#
#          loan  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
df['age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 corr = df.corr()
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/core/frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Uni/Big Data/BData/lib/python3.13/site-packages/pandas/core/frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...
