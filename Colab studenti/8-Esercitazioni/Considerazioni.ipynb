# %% [raw]
# Il decision tree non è basato su distanza euclidea, ma su tagli dei dati, quindi normalizzare o scalare i dati non cambiano le prestazioni

# %% [markdown]
# La linear regression ha prestazioni pietose se sto facendo classificazione, ma ho fatto un encoding sulla classe da predire e alla fine devo fare round, arrrotondare. In quanto lei pensa che 2 sia il doppio di 1, ma in realtà sono due classi completamente diverse
